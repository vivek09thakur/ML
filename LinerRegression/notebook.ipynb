# %% [markdown]
# ## **Linear Regression**
#
# It is a statistical model that estimates the linear relationship between a scalar response and one or more explanatory variables
#
# ![image.png](attachment:image.png)
#
# In linear regression, the dependent variable is the effect, and its value depends on changes in the independent variable. The dependent variable is represented as "y".

# %% [markdown]
# ## **Getting Started**
# > **In this project we are going to use linear regression to predict the prices of pizzas of different sizes**

# %% [markdown]
# 1. **DATASET**

# %%
PizzaPriceDataset = "../LinerRegression/pizza_price.csv"

# %% [markdown]
# 2. **Imports**

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression

# %%
# Reading the dataset
price_data = pd.read_csv(PizzaPriceDataset)

# %%
# Looking at dataset
price_data.head()
# Out:
#    size  price
# 0    10   22.5
# 1    12   27.5
# 2    14   29.5
# 3    16   31.5
# 4    18   33.5

# %% [markdown]
# 3. **Visualizing the dataset**

# %%
plt.plot(price_data['size'],price_data['price'])
plt.title("Increment in price of pizza respect to size of pizza")
plt.xlabel("Pizza Size (In cm^2)")
plt.ylabel("Pizza Price (In rupees)")
plt.show()

# %% [markdown]
# ### **Start Building Linear Regression Model**

# %%
model = LinearRegression()
model.fit(price_data[['size']],price_data[['price']])
# Out:
# LinearRegression()

# %%
new_data = [55]
